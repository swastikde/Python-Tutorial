# %% [markdown]
# # Flask

# %% [markdown]
# ##### Two Important <br> 1. WSGI --> Web Server Gateway Interface. <br> 2. Jinja 2 --> Template Engine

# %% [markdown]
# ##### Basic Idea Of WSGI
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Basic Idea of Jinja-2 Template Engine
# ![image.png](attachment:image.png)
